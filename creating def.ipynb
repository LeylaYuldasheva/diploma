# %%
import dlib
from skimage import io
from scipy.spatial import distance
import cv2
import glob
import sys
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
sp = dlib.shape_predictor('models/shape_predictor_68_face_landmarks.dat')
facerec = dlib.face_recognition_model_v1('models/dlib_face_recognition_resnet_model_v1.dat')
detector = dlib.get_frontal_face_detector()

# %%
def get_descriptors(files):
    pictures = []
    descriptors = []
    for file in tqdm(files):
        img = cv2.imread(file)
        pictures.append(img)
        dets = detector(img, 1)
        for k, d in enumerate(dets):
            #print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
                #k, d.left(), d.top(), d.right(), d.bottom()))
            shape = sp(img, d)
            face_descriptor = facerec.compute_face_descriptor(img, shape)
            item = {
                'descriptor':np.array(face_descriptor),
                'file' : file,
            }
            descriptors.append(item)
    return descriptors

# %%
def get_df(descriptors, name):
    df =pd.DataFrame(columns = ['img_path', 'class', 'descriptor'])

    for item in tqdm(descriptors):
        class1 = name
        desc = item['descriptor']
        descriptor = ' '.join([str(n) for n in desc])
        row ={
            'img_path': item['file'],
            'class': class1,
            'descriptor': descriptor,
        }

        df = df.append(row, ignore_index=True)
    return df

# %%
files1 = glob.glob('Harrison_Ford\\*.PNG')+glob.glob('Harrison_Ford\\*.jpg')
files2 = glob.glob('Emma_Watson\\*.PNG') + glob.glob('Emma_Watson\\*.jpg')
files3 = glob.glob('Rupert_Grint\\*.PNG')+glob.glob('Rupert_Grint\\*.jpg')
files4 = glob.glob('Will_Smith\\*.PNG')+glob.glob('Will_Smith\\*.jpg')
files5 = glob.glob('Halle_Berry\\*.PNG')+glob.glob('Halle_Berry\\*.jpg')
files6 = glob.glob('Dan_Radcliffe\\*.PNG')+glob.glob('Dan_Radcliffe\\*.jpg')

# %%
HF = get_descriptors(files1)
df_HF = get_df(HF, 'Harrison_Ford')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 584/584 [43:31<00:00,  4.47s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 542/542 [00:05<00:00, 100.81it/s]

# %%
df_HF.to_csv('Harrison_Ford.csv')
df_HF.to_excel('Harrison_Ford.xlsx')

# %%
EW = get_descriptors(files2)
df_EW = get_df(EW, 'Emma_Watson')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 344/344 [18:58<00:00,  3.31s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 318/318 [00:02<00:00, 107.16it/s]

# %%
df_EW.to_csv('Emma_Watson.csv')
df_EW.to_excel('Emma_Watson.xlsx')

# %%
RG = get_descriptors(files3)
df_RG = get_df(RG, 'Rupert_Grint')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 837/837 [1:02:42<00:00,  4.49s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 757/757 [00:07<00:00, 100.43it/s]

# %%
df_RG.to_csv('Rupert_Grint.csv')
df_RG.to_excel('Rupert_Grint.xlsx')

# %%
WS = get_descriptors(files4)
df_WS = get_df(WS, 'Will_Smith')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 728/728 [57:08<00:00,  4.71s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 706/706 [00:06<00:00, 103.69it/s]

# %%
df_WS.to_csv('Will_Smith.csv')
df_WS.to_excel('Will_Smith.xlsx')

# %%
HB = get_descriptors(files5)
df_HB = get_df(HB, 'Halle_Berry')
df_HB.to_csv('Halle_Berry.csv')
df_HB.to_excel('Halle_Berry.xlsx')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 662/662 [1:00:46<00:00,  5.51s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 590/590 [00:05<00:00, 102.06it/s]

# %%
DR = get_descriptors(files6)
df_DR = get_df(DR, 'Dan_Radcliffe')
df_DR.to_csv('Dan_Radcliffe.csv')
df_DR.to_excel('Dan_Radcliffe.xlsx')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 411/411 [26:04<00:00,  3.81s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████| 393/393 [00:03<00:00, 105.80it/s]

# %%
df2 = pd.read_csv('Dan_Radcliffe.csv', index_col = 0)

# %%
df2
# Out:
#                   img_path          class  \
# 0     Dan_Radcliffe\10.PNG  Dan_Radcliffe
# 1    Dan_Radcliffe\100.PNG  Dan_Radcliffe
# 2    Dan_Radcliffe\101.PNG  Dan_Radcliffe
# 3    Dan_Radcliffe\102.PNG  Dan_Radcliffe
# 4    Dan_Radcliffe\104.PNG  Dan_Radcliffe
# ..                     ...            ...
# 388  Dan_Radcliffe\472.jpg  Dan_Radcliffe
# 389  Dan_Radcliffe\473.jpg  Dan_Radcliffe
# 390  Dan_Radcliffe\474.jpg  Dan_Radcliffe
# 391  Dan_Radcliffe\475.jpg  Dan_Radcliffe
# 392  Dan_Radcliffe\476.jpg  Dan_Radcliffe
#
#                                             descriptor
# 0    -0.01745985820889473 0.10399903357028961 0.059...
# 1    -0.10777680575847626 0.07684307545423508 0.040...
# 2    -0.10304909199476242 0.08664718270301819 0.038...
# 3    -0.06392291933298111 0.09306670725345612 0.059...
# 4    -0.10605598986148834 0.07336850464344025 -0.03...
# ..                                                 ...
# 388  -0.040038757026195526 0.1165609285235405 0.013...
# 389  -0.005341207142919302 0.19764338433742523 0.04...
# 390  -0.011882415041327477 0.16236011683940887 0.02...
# 391  0.0005403229733929038 0.10192063450813293 0.01...
# 392  0.014902598224580288 0.10690087080001831 -0.01...
#
# [393 rows x 3 columns]

# %%
#adding new images to existed dataframe

# %%
files = glob.glob('Rupert_Grint\\*.jpg')

# %%
old_df = pd.read_csv('Rupert_Grint.csv', index_col = 0)

# %%
new_files = []
for file in files:
    if file in old_df['img_path'].values:
        continue
    else:
        new_files.append(file)

# %%
new_files
# Out:
# ['Rupert_Grint\\242.jpg',
#  'Rupert_Grint\\243.jpg',
#  'Rupert_Grint\\244.jpg',
#  'Rupert_Grint\\245.jpg',
#  'Rupert_Grint\\246.jpg',
#  'Rupert_Grint\\247.jpg',
#  'Rupert_Grint\\248.jpg',
#  'Rupert_Grint\\249.jpg',
#  'Rupert_Grint\\250.jpg',
#  'Rupert_Grint\\251.jpg',
#  'Rupert_Grint\\252.jpg',
#  'Rupert_Grint\\253.jpg',
#  'Rupert_Grint\\254.jpg',
#  'Rupert_Grint\\255.jpg',
#  'Rupert_Grint\\256.jpg',
#  'Rupert_Grint\\257.jpg',
#  'Rupert_Grint\\258.jpg',
#  'Rupert_Grint\\259.jpg',
#  'Rupert_Grint\\260.jpg',
#  'Rupert_Grint\\261.jpg',
#  'Rupert_Grint\\262.jpg',
#  'Rupert_Grint\\263.jpg',
#  'Rupert_Grint\\267.jpg',
#  'Rupert_Grint\\268.jpg',
#  'Rupert_Grint\\269.jpg',
#  'Rupert_Grint\\270.jpg',
#  'Rupert_Grint\\271.jpg',
#  'Rupert_Grint\\272.jpg',
#  'Rupert_Grint\\273.jpg',
#  'Rupert_Grint\\274.jpg',
#  'Rupert_Grint\\275.jpg',
#  'Rupert_Grint\\276.jpg',
#  'Rupert_Grint\\277.jpg',
#  'Rupert_Grint\\278.jpg',
#  'Rupert_Grint\\279.jpg',
#  'Rupert_Grint\\280.jpg',
#  'Rupert_Grint\\281.jpg',
#  'Rupert_Grint\\282.jpg',
#  'Rupert_Grint\\283.jpg',
#  'Rupert_Grint\\284.jpg',
#  'Rupert_Grint\\285.jpg',
#  'Rupert_Grint\\286.jpg',
#  'Rupert_Grint\\287.jpg',
#  'Rupert_Grint\\288.jpg',
#  'Rupert_Grint\\289.jpg',
#  'Rupert_Grint\\290.jpg',
#  'Rupert_Grint\\291.jpg',
#  'Rupert_Grint\\292.jpg',
#  'Rupert_Grint\\293.jpg',
#  'Rupert_Grint\\294.jpg',
#  'Rupert_Grint\\295.jpg',
#  'Rupert_Grint\\296.jpg',
#  'Rupert_Grint\\297.jpg',
#  'Rupert_Grint\\298.jpg',
#  'Rupert_Grint\\299.jpg',
#  'Rupert_Grint\\300.jpg',
#  'Rupert_Grint\\301.jpg',
#  'Rupert_Grint\\302.jpg',
#  'Rupert_Grint\\303.jpg',
#  'Rupert_Grint\\304.jpg',
#  'Rupert_Grint\\305.jpg',
#  'Rupert_Grint\\306.jpg',
#  'Rupert_Grint\\307.jpg',
#  'Rupert_Grint\\308.jpg',
#  'Rupert_Grint\\309.jpg',
#  'Rupert_Grint\\310.jpg',
#  'Rupert_Grint\\311.jpg',
#  'Rupert_Grint\\312.jpg',
#  'Rupert_Grint\\313.jpg',
#  'Rupert_Grint\\314.jpg',
#  'Rupert_Grint\\315.jpg',
#  'Rupert_Grint\\316.jpg',
#  'Rupert_Grint\\317.jpg',
#  'Rupert_Grint\\318.jpg',
#  'Rupert_Grint\\319.jpg',
#  'Rupert_Grint\\320.jpg',
#  'Rupert_Grint\\321.jpg',
#  'Rupert_Grint\\322.jpg',
#  'Rupert_Grint\\323.jpg',
#  'Rupert_Grint\\324.jpg',
#  'Rupert_Grint\\325.jpg',
#  'Rupert_Grint\\326.jpg',
#  'Rupert_Grint\\327.jpg',
#  'Rupert_Grint\\328.jpg',
#  'Rupert_Grint\\329.jpg',
#  'Rupert_Grint\\330.jpg',
#  'Rupert_Grint\\331.jpg',
#  'Rupert_Grint\\332.jpg',
#  'Rupert_Grint\\333.jpg',
#  'Rupert_Grint\\334.jpg',
#  'Rupert_Grint\\335.jpg',
#  'Rupert_Grint\\336.jpg',
#  'Rupert_Grint\\337.jpg',
#  'Rupert_Grint\\338.jpg',
#  'Rupert_Grint\\339.jpg',
#  'Rupert_Grint\\340.jpg',
#  'Rupert_Grint\\341.jpg',
#  'Rupert_Grint\\342.jpg',
#  'Rupert_Grint\\343.jpg',
#  'Rupert_Grint\\344.jpg',
#  'Rupert_Grint\\345.jpg',
#  'Rupert_Grint\\346.jpg',
#  'Rupert_Grint\\347.jpg',
#  'Rupert_Grint\\348.jpg',
#  'Rupert_Grint\\349.jpg',
#  'Rupert_Grint\\350.jpg',
#  'Rupert_Grint\\351.jpg',
#  'Rupert_Grint\\352.jpg',
#  'Rupert_Grint\\353.jpg',
#  'Rupert_Grint\\354.jpg',
#  'Rupert_Grint\\355.jpg',
#  'Rupert_Grint\\356.jpg',
#  'Rupert_Grint\\357.jpg',
#  'Rupert_Grint\\358.jpg',
#  'Rupert_Grint\\359.jpg',
#  'Rupert_Grint\\360.jpg',
#  'Rupert_Grint\\361.jpg',
#  'Rupert_Grint\\362.jpg',
#  'Rupert_Grint\\363.jpg',
#  'Rupert_Grint\\364.jpg',
#  'Rupert_Grint\\365.jpg',
#  'Rupert_Grint\\366.jpg',
#  'Rupert_Grint\\367.jpg',
#  'Rupert_Grint\\368.jpg',
#  'Rupert_Grint\\369.jpg',
#  'Rupert_Grint\\370.jpg',
#  'Rupert_Grint\\371.jpg',
#  'Rupert_Grint\\372.jpg',
#  'Rupert_Grint\\373.jpg',
#  'Rupert_Grint\\374.jpg',
#  'Rupert_Grint\\375.jpg',
#  'Rupert_Grint\\376.jpg',
#  'Rupert_Grint\\377.jpg',
#  'Rupert_Grint\\378.jpg',
#  'Rupert_Grint\\379.jpg',
#  'Rupert_Grint\\380.jpg',
#  'Rupert_Grint\\381.jpg',
#  'Rupert_Grint\\382.jpg',
#  'Rupert_Grint\\383.jpg',
#  'Rupert_Grint\\384.jpg',
#  'Rupert_Grint\\385.jpg',
#  'Rupert_Grint\\386.jpg',
#  'Rupert_Grint\\387.jpg',
#  'Rupert_Grint\\388.jpg',
#  'Rupert_Grint\\389.jpg',
#  'Rupert_Grint\\390.jpg',
#  'Rupert_Grint\\391.jpg',
#  'Rupert_Grint\\392.jpg',
#  'Rupert_Grint\\393.jpg',
#  'Rupert_Grint\\394.jpg',
#  'Rupert_Grint\\395.jpg',
#  'Rupert_Grint\\396.jpg',
#  'Rupert_Grint\\397.jpg',
#  'Rupert_Grint\\398.jpg',
#  'Rupert_Grint\\399.jpg',
#  'Rupert_Grint\\400.jpg',
#  'Rupert_Grint\\401.jpg',
#  'Rupert_Grint\\402.jpg',
#  'Rupert_Grint\\403.jpg',
#  'Rupert_Grint\\404.jpg',
#  'Rupert_Grint\\405.jpg',
#  'Rupert_Grint\\406.jpg',
#  'Rupert_Grint\\407.jpg',
#  'Rupert_Grint\\408.jpg',
#  'Rupert_Grint\\409.jpg',
#  'Rupert_Grint\\410.jpg',
#  'Rupert_Grint\\411.jpg',
#  'Rupert_Grint\\412.jpg',
#  'Rupert_Grint\\413.jpg',
#  'Rupert_Grint\\414.jpg',
#  'Rupert_Grint\\415.jpg',
#  'Rupert_Grint\\416.jpg',
#  'Rupert_Grint\\417.jpg',
#  'Rupert_Grint\\418.jpg',
#  'Rupert_Grint\\419.jpg',
#  'Rupert_Grint\\420.jpg',
#  'Rupert_Grint\\421.jpg',
#  'Rupert_Grint\\422.jpg',
#  'Rupert_Grint\\423.jpg',
#  'Rupert_Grint\\424.jpg',
#  'Rupert_Grint\\425.jpg',
#  'Rupert_Grint\\426.jpg',
#  'Rupert_Grint\\427.jpg',
#  'Rupert_Grint\\428.jpg',
#  'Rupert_Grint\\429.jpg',
#  'Rupert_Grint\\430.jpg',
#  'Rupert_Grint\\431.jpg',
#  'Rupert_Grint\\432.jpg',
#  'Rupert_Grint\\433.jpg',
#  'Rupert_Grint\\434.jpg',
#  'Rupert_Grint\\435.jpg',
#  'Rupert_Grint\\436.jpg',
#  'Rupert_Grint\\437.jpg',
#  'Rupert_Grint\\438.jpg',
#  'Rupert_Grint\\439.jpg',
#  'Rupert_Grint\\440.jpg',
#  'Rupert_Grint\\441.jpg',
#  'Rupert_Grint\\442.jpg',
#  'Rupert_Grint\\443.jpg',
#  'Rupert_Grint\\444.jpg',
#  'Rupert_Grint\\445.jpg',
#  'Rupert_Grint\\446.jpg',
#  'Rupert_Grint\\447.jpg',
#  'Rupert_Grint\\448.jpg',
#  'Rupert_Grint\\449.jpg',
#  'Rupert_Grint\\450.jpg',
#  'Rupert_Grint\\451.jpg',
#  'Rupert_Grint\\452.jpg',
#  'Rupert_Grint\\453.jpg',
#  'Rupert_Grint\\454.jpg',
#  'Rupert_Grint\\455.jpg',
#  'Rupert_Grint\\456.jpg',
#  'Rupert_Grint\\457.jpg',
#  'Rupert_Grint\\458.jpg',
#  'Rupert_Grint\\459.jpg',
#  'Rupert_Grint\\460.jpg',
#  'Rupert_Grint\\461.jpg',
#  'Rupert_Grint\\462.jpg',
#  'Rupert_Grint\\463.jpg',
#  'Rupert_Grint\\464.jpg',
#  'Rupert_Grint\\465.jpg',
#  'Rupert_Grint\\466.jpg',
#  'Rupert_Grint\\467.jpg',
#  'Rupert_Grint\\468.jpg',
#  'Rupert_Grint\\469.jpg',
#  'Rupert_Grint\\470.jpg',
#  'Rupert_Grint\\471.jpg',
#  'Rupert_Grint\\472.jpg',
#  'Rupert_Grint\\473.jpg',
#  'Rupert_Grint\\474.jpg',
#  'Rupert_Grint\\475.jpg',
#  'Rupert_Grint\\476.jpg',
#  'Rupert_Grint\\477.jpg',
#  'Rupert_Grint\\478.jpg',
#  'Rupert_Grint\\479.jpg',
#  'Rupert_Grint\\480.jpg',
#  'Rupert_Grint\\481.jpg',
#  'Rupert_Grint\\482.jpg',
#  'Rupert_Grint\\483.jpg',
#  'Rupert_Grint\\484.jpg',
#  'Rupert_Grint\\485.jpg',
#  'Rupert_Grint\\486.jpg',
#  'Rupert_Grint\\487.jpg',
#  'Rupert_Grint\\488.jpg',
#  'Rupert_Grint\\489.jpg',
#  'Rupert_Grint\\490.jpg',
#  'Rupert_Grint\\491.jpg',
#  'Rupert_Grint\\492.jpg',
#  'Rupert_Grint\\493.jpg',
#  'Rupert_Grint\\494.jpg',
#  'Rupert_Grint\\495.jpg',
#  'Rupert_Grint\\496.jpg',
#  'Rupert_Grint\\497.jpg',
#  'Rupert_Grint\\498.jpg',
#  'Rupert_Grint\\499.jpg',
#  'Rupert_Grint\\500.jpg',
#  'Rupert_Grint\\501.jpg',
#  'Rupert_Grint\\502.jpg',
#  'Rupert_Grint\\503.jpg',
#  'Rupert_Grint\\504.jpg',
#  'Rupert_Grint\\505.jpg',
#  'Rupert_Grint\\506.jpg',
#  'Rupert_Grint\\507.jpg',
#  'Rupert_Grint\\508.jpg',
#  'Rupert_Grint\\509.jpg',
#  'Rupert_Grint\\510.jpg',
#  'Rupert_Grint\\511.jpg',
#  'Rupert_Grint\\512.jpg',
#  'Rupert_Grint\\513.jpg',
#  'Rupert_Grint\\514.jpg',
#  'Rupert_Grint\\515.jpg',
#  'Rupert_Grint\\516.jpg',
#  'Rupert_Grint\\517.jpg',
#  'Rupert_Grint\\518.jpg',
#  'Rupert_Grint\\519.jpg',
#  'Rupert_Grint\\520.jpg',
#  'Rupert_Grint\\521.jpg',
#  'Rupert_Grint\\522.jpg',
#  'Rupert_Grint\\523.jpg',
#  'Rupert_Grint\\524.jpg',
#  'Rupert_Grint\\525.jpg',
#  'Rupert_Grint\\526.jpg',
#  'Rupert_Grint\\527.jpg',
#  'Rupert_Grint\\528.jpg',
#  'Rupert_Grint\\529.jpg',
#  'Rupert_Grint\\530.jpg',
#  'Rupert_Grint\\531.jpg',
#  'Rupert_Grint\\532.jpg',
#  'Rupert_Grint\\533.jpg',
#  'Rupert_Grint\\534.jpg',
#  'Rupert_Grint\\535.jpg',
#  'Rupert_Grint\\536.jpg',
#  'Rupert_Grint\\537.jpg',
#  'Rupert_Grint\\538.jpg',
#  'Rupert_Grint\\539.jpg',
#  'Rupert_Grint\\540.jpg',
#  'Rupert_Grint\\541.jpg',
#  'Rupert_Grint\\542.jpg',
#  'Rupert_Grint\\543.jpg',
#  'Rupert_Grint\\544.jpg',
#  'Rupert_Grint\\545.jpg',
#  'Rupert_Grint\\546.jpg',
#  'Rupert_Grint\\547.jpg',
#  'Rupert_Grint\\548.jpg',
#  'Rupert_Grint\\549.jpg',
#  'Rupert_Grint\\550.jpg',
#  'Rupert_Grint\\551.jpg',
#  'Rupert_Grint\\552.jpg',
#  'Rupert_Grint\\553.jpg',
#  'Rupert_Grint\\554.jpg',
#  'Rupert_Grint\\555.jpg',
#  'Rupert_Grint\\556.jpg',
#  'Rupert_Grint\\557.jpg',
#  'Rupert_Grint\\558.jpg',
#  'Rupert_Grint\\559.jpg',
#  'Rupert_Grint\\560.jpg',
#  'Rupert_Grint\\561.jpg',
#  'Rupert_Grint\\562.jpg',
#  'Rupert_Grint\\563.jpg',
#  'Rupert_Grint\\564.jpg',
#  'Rupert_Grint\\565.jpg',
#  'Rupert_Grint\\566.jpg',
#  'Rupert_Grint\\567.jpg',
#  'Rupert_Grint\\568.jpg',
#  'Rupert_Grint\\569.jpg',
#  'Rupert_Grint\\570.jpg',
#  'Rupert_Grint\\571.jpg',
#  'Rupert_Grint\\572.jpg',
#  'Rupert_Grint\\573.jpg',
#  'Rupert_Grint\\574.jpg',
#  'Rupert_Grint\\575.jpg',
#  'Rupert_Grint\\576.jpg',
#  'Rupert_Grint\\577.jpg',
#  'Rupert_Grint\\578.jpg',
#  'Rupert_Grint\\579.jpg',
#  'Rupert_Grint\\580.jpg',
#  'Rupert_Grint\\581.jpg',
#  'Rupert_Grint\\582.jpg',
#  'Rupert_Grint\\583.jpg',
#  'Rupert_Grint\\584.jpg',
#  'Rupert_Grint\\585.jpg',
#  'Rupert_Grint\\586.jpg',
#  'Rupert_Grint\\587.jpg',
#  'Rupert_Grint\\588.jpg',
#  'Rupert_Grint\\589.jpg',
#  'Rupert_Grint\\590.jpg',
#  'Rupert_Grint\\591.jpg',
#  'Rupert_Grint\\592.jpg',
#  'Rupert_Grint\\593.jpg',
#  'Rupert_Grint\\594.jpg',
#  'Rupert_Grint\\595.jpg',
#  'Rupert_Grint\\596.jpg',
#  'Rupert_Grint\\597.jpg',
#  'Rupert_Grint\\598.jpg',
#  'Rupert_Grint\\599.jpg',
#  'Rupert_Grint\\600.jpg',
#  'Rupert_Grint\\601.jpg',
#  'Rupert_Grint\\602.jpg',
#  'Rupert_Grint\\603.jpg',
#  'Rupert_Grint\\604.jpg',
#  'Rupert_Grint\\605.jpg',
#  'Rupert_Grint\\606.jpg',
#  'Rupert_Grint\\607.jpg',
#  'Rupert_Grint\\608.jpg',
#  'Rupert_Grint\\609.jpg',
#  'Rupert_Grint\\610.jpg',
#  'Rupert_Grint\\611.jpg',
#  'Rupert_Grint\\612.jpg',
#  'Rupert_Grint\\613.jpg',
#  'Rupert_Grint\\614.jpg',
#  'Rupert_Grint\\615.jpg',
#  'Rupert_Grint\\616.jpg',
#  'Rupert_Grint\\617.jpg',
#  'Rupert_Grint\\618.jpg',
#  'Rupert_Grint\\619.jpg',
#  'Rupert_Grint\\620.jpg',
#  'Rupert_Grint\\621.jpg',
#  'Rupert_Grint\\622.jpg',
#  'Rupert_Grint\\623.jpg',
#  'Rupert_Grint\\624.jpg',
#  'Rupert_Grint\\625.jpg',
#  'Rupert_Grint\\626.jpg',
#  'Rupert_Grint\\627.jpg',
#  'Rupert_Grint\\628.jpg',
#  'Rupert_Grint\\629.jpg',
#  'Rupert_Grint\\630.jpg',
#  'Rupert_Grint\\631.jpg',
#  'Rupert_Grint\\632.jpg',
#  'Rupert_Grint\\633.jpg',
#  'Rupert_Grint\\634.jpg',
#  'Rupert_Grint\\635.jpg',
#  'Rupert_Grint\\636.jpg',
#  'Rupert_Grint\\637.jpg',
#  'Rupert_Grint\\638.jpg',
#  'Rupert_Grint\\639.jpg',
#  'Rupert_Grint\\640.jpg',
#  'Rupert_Grint\\641.jpg',
#  'Rupert_Grint\\642.jpg',
#  'Rupert_Grint\\643.jpg',
#  'Rupert_Grint\\644.jpg',
#  'Rupert_Grint\\645.jpg',
#  'Rupert_Grint\\646.jpg',
#  'Rupert_Grint\\647.jpg',
#  'Rupert_Grint\\648.jpg',
#  'Rupert_Grint\\649.jpg',
#  'Rupert_Grint\\650.jpg',
#  'Rupert_Grint\\651.jpg',
#  'Rupert_Grint\\652.jpg',
#  'Rupert_Grint\\653.jpg',
#  'Rupert_Grint\\654.jpg',
#  'Rupert_Grint\\655.jpg',
#  'Rupert_Grint\\656.jpg',
#  'Rupert_Grint\\657.jpg',
#  'Rupert_Grint\\658.jpg',
#  'Rupert_Grint\\659.jpg',
#  'Rupert_Grint\\660.jpg',
#  'Rupert_Grint\\661.jpg',
#  'Rupert_Grint\\662.jpg',
#  'Rupert_Grint\\663.jpg',
#  'Rupert_Grint\\664.jpg',
#  'Rupert_Grint\\665.jpg',
#  'Rupert_Grint\\666.jpg',
#  'Rupert_Grint\\667.jpg',
#  'Rupert_Grint\\668.jpg',
#  'Rupert_Grint\\669.jpg',
#  'Rupert_Grint\\670.jpg',
#  'Rupert_Grint\\671.jpg',
#  'Rupert_Grint\\672.jpg',
#  'Rupert_Grint\\673.jpg',
#  'Rupert_Grint\\674.jpg',
#  'Rupert_Grint\\675.jpg',
#  'Rupert_Grint\\676.jpg',
#  'Rupert_Grint\\677.jpg',
#  'Rupert_Grint\\678.jpg',
#  'Rupert_Grint\\679.jpg',
#  'Rupert_Grint\\680.jpg',
#  'Rupert_Grint\\681.jpg',
#  'Rupert_Grint\\682.jpg',
#  'Rupert_Grint\\683.jpg',
#  'Rupert_Grint\\684.jpg',
#  'Rupert_Grint\\685.jpg',
#  'Rupert_Grint\\686.jpg',
#  'Rupert_Grint\\687.jpg',
#  'Rupert_Grint\\688.jpg',
#  'Rupert_Grint\\689.jpg',
#  'Rupert_Grint\\690.jpg',
#  'Rupert_Grint\\691.jpg',
#  'Rupert_Grint\\692.jpg',
#  'Rupert_Grint\\693.jpg',
#  'Rupert_Grint\\694.jpg',
#  'Rupert_Grint\\695.jpg',
#  'Rupert_Grint\\696.jpg',
#  'Rupert_Grint\\697.jpg',
#  'Rupert_Grint\\698.jpg',
#  'Rupert_Grint\\699.jpg',
#  'Rupert_Grint\\700.jpg',
#  'Rupert_Grint\\701.jpg',
#  'Rupert_Grint\\702.jpg',
#  'Rupert_Grint\\703.jpg',
#  'Rupert_Grint\\704.jpg',
#  'Rupert_Grint\\705.jpg',
#  'Rupert_Grint\\706.jpg',
#  'Rupert_Grint\\707.jpg',
#  'Rupert_Grint\\708.jpg',
#  'Rupert_Grint\\709.jpg',
#  'Rupert_Grint\\710.jpg',
#  'Rupert_Grint\\711.jpg',
#  'Rupert_Grint\\712.jpg',
#  'Rupert_Grint\\713.jpg',
#  'Rupert_Grint\\714.jpg',
#  'Rupert_Grint\\715.jpg',
#  'Rupert_Grint\\716.jpg',
#  'Rupert_Grint\\717.jpg',
#  'Rupert_Grint\\718.jpg',
#  'Rupert_Grint\\719.jpg',
#  'Rupert_Grint\\720.jpg',
#  'Rupert_Grint\\721.jpg',
#  'Rupert_Grint\\722.jpg',
#  'Rupert_Grint\\723.jpg',
#  'Rupert_Grint\\724.jpg',
#  'Rupert_Grint\\725.jpg',
#  'Rupert_Grint\\726.jpg',
#  'Rupert_Grint\\727.jpg',
#  'Rupert_Grint\\728.jpg',
#  'Rupert_Grint\\729.jpg',
#  'Rupert_Grint\\730.jpg',
#  'Rupert_Grint\\731.jpg',
#  'Rupert_Grint\\732.jpg',
#  'Rupert_Grint\\733.jpg',
#  'Rupert_Grint\\734.jpg',
#  'Rupert_Grint\\735.jpg',
#  'Rupert_Grint\\736.jpg',
#  'Rupert_Grint\\737.jpg',
#  'Rupert_Grint\\738.jpg',
#  'Rupert_Grint\\739.jpg',
#  'Rupert_Grint\\740.jpg',
#  'Rupert_Grint\\741.jpg',
#  'Rupert_Grint\\742.jpg',
#  'Rupert_Grint\\743.jpg',
#  'Rupert_Grint\\744.jpg',
#  'Rupert_Grint\\745.jpg',
#  'Rupert_Grint\\746.jpg',
#  'Rupert_Grint\\747.jpg',
#  'Rupert_Grint\\748.jpg',
#  'Rupert_Grint\\749.jpg',
#  'Rupert_Grint\\750.jpg',
#  'Rupert_Grint\\751.jpg',
#  'Rupert_Grint\\752.jpg',
#  'Rupert_Grint\\753.jpg',
#  'Rupert_Grint\\754.jpg',
#  'Rupert_Grint\\755.jpg',
#  'Rupert_Grint\\756.jpg',
#  'Rupert_Grint\\757.jpg',
#  'Rupert_Grint\\758.jpg',
#  'Rupert_Grint\\759.jpg',
#  'Rupert_Grint\\760.jpg',
#  'Rupert_Grint\\761.jpg',
#  'Rupert_Grint\\762.jpg',
#  'Rupert_Grint\\763.jpg',
#  'Rupert_Grint\\764.jpg',
#  'Rupert_Grint\\765.jpg',
#  'Rupert_Grint\\766.jpg',
#  'Rupert_Grint\\767.jpg',
#  'Rupert_Grint\\768.jpg',
#  'Rupert_Grint\\769.jpg',
#  'Rupert_Grint\\770.jpg',
#  'Rupert_Grint\\771.jpg',
#  'Rupert_Grint\\772.jpg',
#  'Rupert_Grint\\773.jpg',
#  'Rupert_Grint\\774.jpg',
#  'Rupert_Grint\\775.jpg',
#  'Rupert_Grint\\776.jpg',
#  'Rupert_Grint\\777.jpg',
#  'Rupert_Grint\\778.jpg',
#  'Rupert_Grint\\779.jpg',
#  'Rupert_Grint\\780.jpg',
#  'Rupert_Grint\\781.jpg',
#  'Rupert_Grint\\782.jpg',
#  'Rupert_Grint\\783.jpg',
#  'Rupert_Grint\\784.jpg',
#  'Rupert_Grint\\785.jpg',
#  'Rupert_Grint\\786.jpg',
#  'Rupert_Grint\\787.jpg',
#  'Rupert_Grint\\788.jpg',
#  'Rupert_Grint\\789.jpg',
#  'Rupert_Grint\\790.jpg',
#  'Rupert_Grint\\791.jpg',
#  'Rupert_Grint\\792.jpg',
#  'Rupert_Grint\\793.jpg',
#  'Rupert_Grint\\794.jpg',
#  'Rupert_Grint\\795.jpg',
#  'Rupert_Grint\\796.jpg',
#  'Rupert_Grint\\797.jpg',
#  'Rupert_Grint\\798.jpg',
#  'Rupert_Grint\\799.jpg',
#  'Rupert_Grint\\800.jpg',
#  'Rupert_Grint\\801.jpg',
#  'Rupert_Grint\\802.jpg',
#  'Rupert_Grint\\803.jpg',
#  'Rupert_Grint\\804.jpg',
#  'Rupert_Grint\\805.jpg',
#  'Rupert_Grint\\806.jpg',
#  'Rupert_Grint\\807.jpg',
#  'Rupert_Grint\\808.jpg',
#  'Rupert_Grint\\809.jpg',
#  'Rupert_Grint\\810.jpg',
#  'Rupert_Grint\\811.jpg',
#  'Rupert_Grint\\812.jpg',
#  'Rupert_Grint\\813.jpg',
#  'Rupert_Grint\\814.jpg',
#  'Rupert_Grint\\815.jpg',
#  'Rupert_Grint\\816.jpg',
#  'Rupert_Grint\\817.jpg',
#  'Rupert_Grint\\818.jpg',
#  'Rupert_Grint\\819.jpg',
#  'Rupert_Grint\\820.jpg',
#  'Rupert_Grint\\821.jpg',
#  'Rupert_Grint\\822.jpg',
#  'Rupert_Grint\\823.jpg',
#  'Rupert_Grint\\824.jpg',
#  'Rupert_Grint\\825.jpg',
#  'Rupert_Grint\\826.jpg',
#  'Rupert_Grint\\827.jpg',
#  'Rupert_Grint\\828.jpg',
#  'Rupert_Grint\\829.jpg',
#  'Rupert_Grint\\830.jpg',
#  'Rupert_Grint\\831.jpg',
#  'Rupert_Grint\\832.jpg',
#  'Rupert_Grint\\833.jpg',
#  'Rupert_Grint\\834.jpg',
#  'Rupert_Grint\\835.jpg',
#  'Rupert_Grint\\836.jpg',
#  'Rupert_Grint\\837.jpg',
#  'Rupert_Grint\\838.jpg',
#  'Rupert_Grint\\839.jpg']

# %%
new_pictures = []
new_descriptors = []

# %%
for file in tqdm(new_files):
    img = cv2.imread(file)
    new_pictures.append(img)
    dets = detector(img, 1)
    for k, d in enumerate(dets):
        shape = sp(img, d)
        face_descriptor = facerec.compute_face_descriptor(img, shape)
        item = {
            'descriptor':face_descriptor,
            'file' : file,
        }
        new_descriptors.append(item)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 595/595 [58:04<00:00,  5.86s/it]

# %%
new_df =pd.DataFrame(columns = ['img_path', 'class', 'descriptor'])

for item in tqdm(new_descriptors):
    class1 = 'Rupert_Grint'
    desc = item['descriptor']
    descriptor = ' '.join([str(n) for n in desc])
    row ={
        'img_path': item['file'],
        'class': class1,
        'descriptor': descriptor,
    }

    new_df = new_df.append(row, ignore_index=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 593/593 [00:06<00:00, 88.89it/s]

# %%
new_df
# Out:
#                  img_path         class  \
# 0    Rupert_Grint\242.jpg  Rupert_Grint
# 1    Rupert_Grint\243.jpg  Rupert_Grint
# 2    Rupert_Grint\244.jpg  Rupert_Grint
# 3    Rupert_Grint\245.jpg  Rupert_Grint
# 4    Rupert_Grint\246.jpg  Rupert_Grint
# ..                    ...           ...
# 588  Rupert_Grint\835.jpg  Rupert_Grint
# 589  Rupert_Grint\836.jpg  Rupert_Grint
# 590  Rupert_Grint\837.jpg  Rupert_Grint
# 591  Rupert_Grint\838.jpg  Rupert_Grint
# 592  Rupert_Grint\839.jpg  Rupert_Grint
#
#                                             descriptor
# 0    -0.05237310379743576 0.07127876579761505 0.059...
# 1    -0.04176531732082367 0.05777474120259285 0.005...
# 2    -0.06902678310871124 0.09710950404405594 0.056...
# 3    -0.05518348887562752 0.05615098029375076 0.057...
# 4    -0.028674466535449028 -0.012040446512401104 0....
# ..                                                 ...
# 588  -0.06006047502160072 0.0023433445021510124 0.0...
# 589  -0.04914705455303192 0.06058773770928383 0.053...
# 590  -0.04880763217806816 0.10131653398275375 0.001...
# 591  -0.07579626888036728 0.07690523564815521 0.019...
# 592  -0.10732926428318024 0.07208702713251114 0.058...
#
# [593 rows x 3 columns]

# %%
total_df = pd.concat([old_df, new_df])

# %%
total_df
# Out:
#                  img_path         class  \
# 0     Rupert_Grint\10.PNG  Rupert_Grint
# 1    Rupert_Grint\100.PNG  Rupert_Grint
# 2    Rupert_Grint\101.PNG  Rupert_Grint
# 3    Rupert_Grint\102.PNG  Rupert_Grint
# 4    Rupert_Grint\103.PNG  Rupert_Grint
# ..                    ...           ...
# 588  Rupert_Grint\835.jpg  Rupert_Grint
# 589  Rupert_Grint\836.jpg  Rupert_Grint
# 590  Rupert_Grint\837.jpg  Rupert_Grint
# 591  Rupert_Grint\838.jpg  Rupert_Grint
# 592  Rupert_Grint\839.jpg  Rupert_Grint
#
#                                             descriptor
# 0    -0.04188723862171173 0.08876699954271317 -0.00...
# 1    0.0034476229920983315 0.04783119261264801 0.05...
# 2    -0.0802157074213028 0.026016555726528168 0.021...
# 3    -0.10715584456920624 0.024501046165823936 0.01...
# 4    -0.0665271133184433 0.039051465690135956 0.011...
# ..                                                 ...
# 588  -0.06006047502160072 0.0023433445021510124 0.0...
# 589  -0.04914705455303192 0.06058773770928383 0.053...
# 590  -0.04880763217806816 0.10131653398275375 0.001...
# 591  -0.07579626888036728 0.07690523564815521 0.019...
# 592  -0.10732926428318024 0.07208702713251114 0.058...
#
# [757 rows x 3 columns]

# %%
total_df.to_csv('Rupert_Grint.csv')
total_df.to_excel('Rupert_Grint.xlsx')

# %%
def add_new_descriptors(files, old_df):
    new_files = []
    new_pictures = []
    new_descriptors = []
    for file in files:
        if file in old_df['img_path'].values:
            continue
        else:
            new_files.append(file)
    for file in tqdm(new_files):
        img = cv2.imread(file)
        new_pictures.append(img)
        dets = detector(img, 1)
        for k, d in enumerate(dets):
            shape = sp(img, d)
            face_descriptor = facerec.compute_face_descriptor(img, shape)
            item = {
            'descriptor':face_descriptor,
            'file' : file,
            }
        new_descriptors.append(item)
    return new_descriptors

# %%
def add_new_images(new_descriptors, name):
    new_df =pd.DataFrame(columns = ['img_path', 'class', 'descriptor'])
    for item in tqdm(new_descriptors):
        class1 = name
        desc = item['descriptor']
        descriptor = ' '.join([str(n) for n in desc])
        row ={
            'img_path': item['file'],
            'class': class1,
            'descriptor': descriptor,
        }

        new_df = new_df.append(row, ignore_index=True)
    return new_df

# %%
def make_and_save_total(old_df, new_df, name):
    total_df = pd.concat([old_df, new_df])
    total_df
    total_df.to_csv(f'{name}.csv')
    total_df.to_excel(f'{name}.xlsx')

# %%
old_df_ew = pd.read_csv('Emma_Watson.csv', index_col = 0)
files_ew = glob.glob('Emma_Watson\\*.jpg')
ew = add_new_descriptors(files_ew, old_df_ew)
ewdf = add_new_images(ew, 'Emma_Watson')
make_and_save_total(old_df_ew,ewdf, 'Emma_Watson' )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [13:31<00:00,  6.24s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [00:01<00:00, 72.90it/s]

# %%
old_df_hb = pd.read_csv('Halle_Berry.csv', index_col = 0)
files_hb = glob.glob('Halle_Berry\\*.jpg')
hb = add_new_descriptors(files_hb, old_df_hb)
hbdf = add_new_images(hb, 'Halle_Berry')
make_and_save_total(old_df_hb,hbdf, 'Halle_Berry' )
# Out:
#  10%|████████                                                                         | 66/662 [06:35<59:30,  5.99s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-993051a3af8b> in <module>
#       1 old_df_hb = pd.read_csv('Halle_Berry.csv', index_col = 0)
#       2 files_hb = glob.glob('Halle_Berry\\*.jpg')
# ----> 3 hb = add_new_descriptors(files_hb, old_df_hb)
#       4 hbdf = add_new_images(hb, 'Halle_Berry')
#       5 make_and_save_total(old_df_hb,hbdf, 'Halle_Berry' )
#
# <ipython-input-104-20ef44d027dc> in add_new_descriptors(files, old_df)
#      12         new_pictures.append(img)
#      13         dets = detector(img, 1)
# ---> 14         for k, d in enumerate(dets):
#      15             shape = sp(img, d)
#      16             face_descriptor = facerec.compute_face_descriptor(img, shape)
#
# KeyboardInterrupt:

# %%
old_df_ws = pd.read_csv('Will_Smith.csv', index_col = 0)
files_ws = glob.glob('Will_Smith\\*.jpg')
ws = add_new_descriptors(files_ws, old_df_ws)
wsdf = add_new_images(ws, 'Will_Smith')
make_and_save_total(old_df_ws,wsdf, 'Will_Smith' )
